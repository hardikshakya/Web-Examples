# %%
import numpy as np
import pandas as pd

# %%
traffic_df = pd.read_csv('trafficdata.csv', delimiter = ';')

# %%
traffic_df
# Out:
#            index           Area ONS LACode             City      CP  S Ref E  \
# 0              0     Merseyside  E08000011         Knowsley  910004   352100
# 1              1     Merseyside  E08000011         Knowsley  910004   352100
# 2              2     Merseyside  E08000011         Knowsley  910004   352100
# 3              3     Merseyside  E08000011         Knowsley  910004   352100
# 4              4     Merseyside  E08000011         Knowsley  910004   352100
# 5              5     Merseyside  E08000011         Knowsley  910004   352100
# 6              6     Merseyside  E08000011         Knowsley  910004   352100
# 7              7     Merseyside  E08000011         Knowsley  910004   352100
# 8              8     Merseyside  E08000011         Knowsley  910004   352100
# 9              9     Merseyside  E08000011         Knowsley  910004   352100
# 10            10     Merseyside  E08000011         Knowsley  910004   352100
# ...

# %%
traffic_df.head()
# Out:
#    index        Area ONS LACode      City      CP  S Ref E  S Ref N  \
# 0      0  Merseyside  E08000011  Knowsley  910004   352100   398200
# 1      1  Merseyside  E08000011  Knowsley  910004   352100   398200
# 2      2  Merseyside  E08000011  Knowsley  910004   352100   398200
# 3      3  Merseyside  E08000011  Knowsley  910004   352100   398200
# 4      4  Merseyside  E08000011  Knowsley  910004   352100   398200
#
#    S_Ref_Latitude  S_Ref_Longitude Road  ...   LGV HGVR2 HGVR3 HGVR4  HGVA3  \
# 0       53.478334        -2.723204    U  ...     2   0.0   0.0   0.0      0
# 1       53.478334        -2.723204    U  ...     2   0.0   0.0   0.0      0
# 2       53.478334        -2.723204    U  ...     1   1.0   0.0   0.0      0
# 3       53.478334        -2.723204    U  ...     2   0.0   0.0   0.0      0
# 4       53.478334        -2.723204    U  ...     1   0.0   0.0   0.0      0
#
#   HGVA5  HGVA6  HGV   AMV  hours
# 0     0      0  0.0   7.0      0
# ...

# %%
traffic_df.count()
# Out:
# index              1743060
# Area               1743060
# ONS LACode         1743060
# City               1743060
# CP                 1743060
# S Ref E            1743060
# S Ref N            1743060
# S_Ref_Latitude     1743060
# S_Ref_Longitude    1743060
# Road               1743060
# Road_Name          1571774
# CP Location         718714
# RCat               1743060
# iDir               1743060
# Year               1743060
# dCount             1743060
# PC                 1743060
# 2WMV               1743060
# CAR                1743060
# BUS                1743060
# LGV                1743060
# HGVR2              1743060
# HGVR3              1743060
# HGVR4              1743060
# HGVA3              1743060
# HGVA5              1743060
# HGVA6              1743060
# HGV                1743060
# AMV                1743060
# hours              1743060
# dtype: int64

# %%
traffic_df.groupby('Area').sum()
# Out:
#                                index            CP       S Ref E      S Ref N  \
# Area
# East Midlands           111952466310  126532022016   62098908780  43823788608
# East of England         181232293512  198154521096  117785901168  51285959808
# London                  102748286496  112684981848   62713851744  21207538872
# Merseyside               28689845778   31160322720   11127970764  12903209124
# North East               73374038153   81349523775   36842405522  46969676892
# North West              129143437872  144989319924   55864200828  63586085604
# Scotland                 94995890914  102074962188   31817415748  75835753328
# South East              259754894261  278171964327  147358250096  44199596964
# South West              146466541068  166094392380   58940361400  23049508860
# Wales                   101344563574  104373350750   32414986646  25489840010
# West Midlands           159591190077  170903057361   71876308695  52105776354
# ...

# %%
traffic_df.groupby('Area').count()
# Out:
#                          index  ONS LACode    City      CP  S Ref E  S Ref N  \
# Area
# East Midlands           133500      133500  133500  133500   133500   133500
# East of England         208752      208752  208752  208752   208752   208752
# London                  118416      118416  118416  118416   118416   118416
# Merseyside               32868       32868   32868   32868    32868    32868
# North East               85559       85559   85559   85559    85559    85559
# North West              152712      152712  152712  152712   152712   152712
# Scotland                106604      106604  106604  106604   106604   106604
# South East              292739      292739  292739  292739   292739   292739
# South West              174416      174416  174416  174416   174416   174416
# Wales                   109702      109702  109702  109702   109702   109702
# West Midlands           179655      179655  179655  179655   179655   179655
# ...

# %%
traffic_df.groupby('City').count()
# Out:
#                               index   Area  ONS LACode     CP  S Ref E  \
# City
# Aberdeen City                  3924   3924        3924   3924     3924
# Aberdeenshire                  8040   8040        8040   8040     8040
# Angus                          3144   3144        3144   3144     3144
# Argyll & Bute                  2256   2256        2256   2256     2256
# Barking and Dagenham           2160   2160        2160   2160     2160
# Barnet                         4200   4200        4200   4200     4200
# Barnsley                       5952   5952        5952   5952     5952
# Bath and North East Somerset   4836   4836        4836   4836     4836
# Bedford                        4776   4776        4776   4776     4776
# Bexley                         2988   2988        2988   2988     2988
# Birmingham                    32076  32076       32076  32076    32076
# Blackburn with Darwen          3048   3048        3048   3048     3048
# ...

# %%
traffic_df[traffic_df.City == 'Knowsley'].groupby(['Area']).count()
# Out:
#             index  ONS LACode  City    CP  S Ref E  S Ref N  S_Ref_Latitude  \
# Area
# Merseyside   5460        5460  5460  5460     5460     5460            5460
#
#             S_Ref_Longitude  Road  Road_Name  ...     LGV  HGVR2  HGVR3  \
# Area                                          ...
# Merseyside             5460  5460       5196  ...    5460   5460   5460
#
#             HGVR4  HGVA3  HGVA5  HGVA6   HGV   AMV  hours
# Area
# Merseyside   5460   5460   5460   5460  5460  5460   5460
#
# [1 rows x 29 columns]

# %%
traffic_df[traffic_df.City == 'Knowsley']
# Out:
#            index        Area ONS LACode      City      CP  S Ref E  S Ref N  \
# 0              0  Merseyside  E08000011  Knowsley  910004   352100   398200
# 1              1  Merseyside  E08000011  Knowsley  910004   352100   398200
# 2              2  Merseyside  E08000011  Knowsley  910004   352100   398200
# 3              3  Merseyside  E08000011  Knowsley  910004   352100   398200
# 4              4  Merseyside  E08000011  Knowsley  910004   352100   398200
# 5              5  Merseyside  E08000011  Knowsley  910004   352100   398200
# 6              6  Merseyside  E08000011  Knowsley  910004   352100   398200
# 7              7  Merseyside  E08000011  Knowsley  910004   352100   398200
# 8              8  Merseyside  E08000011  Knowsley  910004   352100   398200
# 9              9  Merseyside  E08000011  Knowsley  910004   352100   398200
# 10            10  Merseyside  E08000011  Knowsley  910004   352100   398200
# ...

# %%
traffic_df[traffic_df.City == 'Knowsley'][['Area','Year','dCount','Road_Name','hours']]
# Out:
#                Area  Year      dCount       Road_Name  hours
# 0        Merseyside  2000  2000-06-08  Dunmail Avenue      0
# 1        Merseyside  2000  2000-06-08  Dunmail Avenue      1
# 2        Merseyside  2000  2000-06-08  Dunmail Avenue      2
# 3        Merseyside  2000  2000-06-08  Dunmail Avenue      3
# 4        Merseyside  2000  2000-06-08  Dunmail Avenue      4
# 5        Merseyside  2000  2000-06-08  Dunmail Avenue      5
# 6        Merseyside  2000  2000-06-08  Dunmail Avenue      6
# 7        Merseyside  2000  2000-06-08  Dunmail Avenue      7
# 8        Merseyside  2000  2000-06-08  Dunmail Avenue      8
# 9        Merseyside  2000  2000-06-08  Dunmail Avenue      9
# 10       Merseyside  2000  2000-06-08  Dunmail Avenue     10
# 11       Merseyside  2000  2000-06-08  Dunmail Avenue     11
# 12       Merseyside  2000  2000-06-08  Dunmail Avenue     12
# 13       Merseyside  2000  2000-06-08  Dunmail Avenue     13
# ...

# %%
traffic_df[traffic_df.City == 'Angus'][['Area','Year','dCount','hours']]
# Out:
#              Area  Year      dCount  hours
# 624      Scotland  2000  2000-09-26      0
# 625      Scotland  2000  2000-09-26      1
# 626      Scotland  2000  2000-09-26      2
# 627      Scotland  2000  2000-09-26      3
# 628      Scotland  2000  2000-09-26      4
# 629      Scotland  2000  2000-09-26      5
# 630      Scotland  2000  2000-09-26      6
# 631      Scotland  2000  2000-09-26      7
# 632      Scotland  2000  2000-09-26      8
# 633      Scotland  2000  2000-09-26      9
# 634      Scotland  2000  2000-09-26     10
# 635      Scotland  2000  2000-09-26     11
# 636      Scotland  2000  2000-09-26     12
# 637      Scotland  2000  2000-09-26     13
# 638      Scotland  2000  2000-09-26     14
# 639      Scotland  2000  2000-09-26     15
# 640      Scotland  2000  2000-09-26     16
# 641      Scotland  2000  2000-09-26     17
# 642      Scotland  2000  2000-09-26     18
# 643      Scotland  2000  2000-09-26     19
# 644      Scotland  2000  2000-09-26     20
# ...

# %%
traffic_df[traffic_df.City == 'Angus'].head()[['Area','Year','dCount','hours']]
# Out:
#          Area  Year      dCount  hours
# 624  Scotland  2000  2000-09-26      0
# 625  Scotland  2000  2000-09-26      1
# 626  Scotland  2000  2000-09-26      2
# 627  Scotland  2000  2000-09-26      3
# 628  Scotland  2000  2000-09-26      4

# %%
traffic_df[traffic_df.City == 'Angus'].groupby(['Road_Name']).count()[['Area','Year','dCount','CAR','BUS', 'LGV','HGVR2','HGVR3','HGVR4','HGVA3','HGVA5','HGVA6','HGV','AMV','hours']]
# Out:
#                   Area  Year  dCount  CAR  BUS  LGV  HGVR2  HGVR3  HGVR4  \
# Road_Name
# Craig Road         360   360     360  360  360  360    360    360    360
# Elmfield Avenue    360   360     360  360  360  360    360    360    360
# Horologe Hill      360   360     360  360  360  360    360    360    360
# Meigle Road        312   312     312  312  312  312    312    312    312
# Montrose Road       24    24      24   24   24   24     24     24     24
# Scott Street       336   336     336  336  336  336    336    336    336
# Threewells Drive   288   288     288  288  288  288    288    288    288
#
#                   HGVA3  HGVA5  HGVA6  HGV  AMV  hours
# Road_Name
# Craig Road          360    360    360  360  360    360
# Elmfield Avenue     360    360    360  360  360    360
# Horologe Hill       360    360    360  360  360    360
# Meigle Road         312    312    312  312  312    312
# Montrose Road        24     24     24   24   24     24
# ...

# %%
traffic_df['AMV'].sum()
# Out:
# 247581310.0

# %%
traffic_df1 = traffic_df[traffic_df.City == 'Knowsley']

# %%
traffic_df2 = traffic_df1[traffic_df1.Area == 'Merseyside']

# %%
traffic_df2[['Area','Year','dCount','CAR','BUS', 'LGV','HGVR2','HGVR3','HGVR4','HGVA3','HGVA5','HGVA6','HGV','AMV','hours']]
# Out:
#                Area  Year      dCount  CAR   BUS  LGV  HGVR2  HGVR3  HGVR4  \
# 0        Merseyside  2000  2000-06-08    4   1.0    2    0.0    0.0    0.0
# 1        Merseyside  2000  2000-06-08    9   0.0    2    0.0    0.0    0.0
# 2        Merseyside  2000  2000-06-08    4   1.0    1    1.0    0.0    0.0
# 3        Merseyside  2000  2000-06-08    6   1.0    2    0.0    0.0    0.0
# 4        Merseyside  2000  2000-06-08   10   1.0    1    0.0    0.0    0.0
# 5        Merseyside  2000  2000-06-08   11   1.0    1    0.0    0.0    0.0
# 6        Merseyside  2000  2000-06-08   11   1.0    2    0.0    0.0    0.0
# 7        Merseyside  2000  2000-06-08   10   1.0    2    1.0    0.0    0.0
# 8        Merseyside  2000  2000-06-08    6   1.0    4    0.0    0.0    0.0
# 9        Merseyside  2000  2000-06-08   13   1.0    2    0.0    0.0    0.0
# 10       Merseyside  2000  2000-06-08   17   0.0    2    0.0    0.0    0.0
# ...

# %%
traffic_df3 = traffic_df2[traffic_df2.dCount == '2000-06-08']

# %%
traffic_df3[['Area','Year','dCount','CAR','BUS', 'LGV','HGVR2','HGVR3','HGVR4','HGVA3','HGVA5','HGVA6','HGV','AMV','hours']]
# Out:
#           Area  Year      dCount  CAR  BUS  LGV  HGVR2  HGVR3  HGVR4  HGVA3  \
# 0   Merseyside  2000  2000-06-08    4  1.0    2    0.0    0.0    0.0      0
# 1   Merseyside  2000  2000-06-08    9  0.0    2    0.0    0.0    0.0      0
# 2   Merseyside  2000  2000-06-08    4  1.0    1    1.0    0.0    0.0      0
# 3   Merseyside  2000  2000-06-08    6  1.0    2    0.0    0.0    0.0      0
# 4   Merseyside  2000  2000-06-08   10  1.0    1    0.0    0.0    0.0      0
# 5   Merseyside  2000  2000-06-08   11  1.0    1    0.0    0.0    0.0      0
# 6   Merseyside  2000  2000-06-08   11  1.0    2    0.0    0.0    0.0      0
# 7   Merseyside  2000  2000-06-08   10  1.0    2    1.0    0.0    0.0      0
# 8   Merseyside  2000  2000-06-08    6  1.0    4    0.0    0.0    0.0      0
# 9   Merseyside  2000  2000-06-08   13  1.0    2    0.0    0.0    0.0      0
# 10  Merseyside  2000  2000-06-08   17  0.0    2    0.0    0.0    0.0      0
# ...

# %%
traffic_df4 = traffic_df3[traffic_df3.hours == 1]

# %%
traffic_df4[['Area','Year','dCount','CAR','BUS', 'LGV','HGVR2','HGVR3','HGVR4','HGVA3','HGVA5','HGVA6','HGV','AMV','hours']]
# Out:
#          Area  Year      dCount  CAR  BUS  LGV  HGVR2  HGVR3  HGVR4  HGVA3  \
# 1  Merseyside  2000  2000-06-08    9  0.0    2    0.0    0.0    0.0      0
#
#    HGVA5  HGVA6  HGV   AMV  hours
# 1      0      0  0.0  11.0      1

# %%
traffic_df1 = traffic_df[traffic_df.City == 'Knowsley']
traffic_df2 = traffic_df1[traffic_df1.Area == 'Merseyside']
traffic_df3 = traffic_df2[traffic_df2.dCount == '2000-06-08']
traffic_df4 = traffic_df3[traffic_df3.hours == 1]

# %%
traffic_df4[['Area','Year','dCount','CAR','BUS', 'LGV','HGVR2','HGVR3','HGVR4','HGVA3','HGVA5','HGVA6','HGV','AMV','hours']]
# Out:
#          Area  Year      dCount  CAR  BUS  LGV  HGVR2  HGVR3  HGVR4  HGVA3  \
# 1  Merseyside  2000  2000-06-08    9  0.0    2    0.0    0.0    0.0      0
#
#    HGVA5  HGVA6  HGV   AMV  hours
# 1      0      0  0.0  11.0      1

# %%
car_num = traffic_df4['CAR'].sum()
bus_num = traffic_df4['BUS'].sum()
lgv_num = traffic_df4['LGV'].sum()
h2_num = traffic_df4['HGVR2'].sum()
h3_num = traffic_df4['HGVR3'].sum()
h4_num = traffic_df4['HGVR4'].sum()
v3_num = traffic_df4['HGVA3'].sum()
v5_num = traffic_df4['HGVA5'].sum()
v6_num = traffic_df4['HGVA6'].sum()
hgv_num = traffic_df4['HGV'].sum()
amv_num = traffic_df4['AMV'].sum()

# %%
veh_sum = car_num + bus_num + lgv_num + h2_num + h3_num + h4_num + v3_num + v5_num + v6_num + hgv_num + amv_num

# %%
veh_sum
# Out:
# 22.0
