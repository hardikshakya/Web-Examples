# %%
import numpy as np
import pandas as pd

# %%
traffic_df = pd.read_csv('trafficdata.csv', delimiter = ';')

# %%
traffic_df
# Out:
#            index           City ONS LACode             Area      CP  S Ref E  \
# 0              0     Merseyside  E08000011         Knowsley  910004   352100
# 1              1     Merseyside  E08000011         Knowsley  910004   352100
# 2              2     Merseyside  E08000011         Knowsley  910004   352100
# 3              3     Merseyside  E08000011         Knowsley  910004   352100
# 4              4     Merseyside  E08000011         Knowsley  910004   352100
# 5              5     Merseyside  E08000011         Knowsley  910004   352100
# 6              6     Merseyside  E08000011         Knowsley  910004   352100
# 7              7     Merseyside  E08000011         Knowsley  910004   352100
# 8              8     Merseyside  E08000011         Knowsley  910004   352100
# 9              9     Merseyside  E08000011         Knowsley  910004   352100
# 10            10     Merseyside  E08000011         Knowsley  910004   352100
# ...

# %%
traffic_df.groupby('City').count()
# Out:
#                           Area    Year  dCount     CAR     BUS     LGV  \
# City
# East Midlands           133500  133500  133500  133500  133500  133500
# East of England         208752  208752  208752  208752  208752  208752
# London                  118416  118416  118416  118416  118416  118416
# Merseyside               32868   32868   32868   32868   32868   32868
# North East               85559   85559   85559   85559   85559   85559
# North West              152712  152712  152712  152712  152712  152712
# Scotland                106604  106604  106604  106604  106604  106604
# South East              292739  292739  292739  292739  292739  292739
# South West              174416  174416  174416  174416  174416  174416
# Wales                   109702  109702  109702  109702  109702  109702
# West Midlands           179655  179655  179655  179655  179655  179655
# Yorkshire & the Humber  148137  148137  148137  148137  148137  148137
#
# ...

# %%
traffic_dff1 = traffic_df[traffic_df.City == 'East Midlands']
traffic_dff1.groupby(['Area']).count()
# Out:
#                   index   City  ONS LACode     CP  S Ref E  S Ref N  \
# Area
# Derby              9216   9216        9216   9216     9216     9216
# Derbyshire        23712  23712       23712  23712    23712    23712
# Leicester          7536   7536        7536   7536     7536     7536
# Leicestershire    21696  21696       21696  21696    21696    21696
# Lincolnshire      19740  19740       19740  19740    19740    19740
# Northamptonshire  21564  21564       21564  21564    21564    21564
# Nottingham         7476   7476        7476   7476     7476     7476
# Nottinghamshire   21000  21000       21000  21000    21000    21000
# Rutland            1560   1560        1560   1560     1560     1560
#
#                   S_Ref_Latitude  S_Ref_Longitude   Road  Road_Name  ...    \
# Area                                                                 ...
# Derby                       9216             9216   9216       9000  ...
# ...

# %%
traffic_dff2 = traffic_df[traffic_df.City == 'East of England']
traffic_dff2.groupby(['Area']).count()
# Out:
#                       index   City  ONS LACode     CP  S Ref E  S Ref N  \
# Area
# Bedford                4776   4776        4776   4776     4776     4776
# Cambridgeshire        22524  22524       22524  22524    22524    22524
# Central Bedfordshire   6420   6420        6420   6420     6420     6420
# Essex                 57432  57432       57432  57432    57432    57432
# Hertfordshire         36312  36312       36312  36312    36312    36312
# Luton                  4740   4740        4740   4740     4740     4740
# Norfolk               35880  35880       35880  35880    35880    35880
# Peterborough           8256   8256        8256   8256     8256     8256
# Southend-on-Sea        4032   4032        4032   4032     4032     4032
# Suffolk               23232  23232       23232  23232    23232    23232
# Thurrock               5148   5148        5148   5148     5148     5148
#
#                       S_Ref_Latitude  S_Ref_Longitude   Road  Road_Name  \
# Area
# ...

# %%
traffic_dff3 = traffic_df[traffic_df.City == 'London']
traffic_dff3.groupby(['Area']).count()
# Out:
#                         index  City  ONS LACode    CP  S Ref E  S Ref N  \
# Area
# Barking and Dagenham     2160  2160        2160  2160     2160     2160
# Barnet                   4200  4200        4200  4200     4200     4200
# Bexley                   2988  2988        2988  2988     2988     2988
# Brent                    3972  3972        3972  3972     3972     3972
# Bromley                  6840  6840        6840  6840     6840     6840
# Camden                   2484  2484        2484  2484     2484     2484
# City of London           1056  1056        1056  1056     1056     1056
# Croydon                  6720  6720        6720  6720     6720     6720
# Ealing                   4860  4860        4860  4860     4860     4860
# Enfield                  3312  3312        3312  3312     3312     3312
# Greenwich                4212  4212        4212  4212     4212     4212
# Hackney                  2352  2352        2352  2352     2352     2352
# ...

# %%
traffic_dff4 = traffic_df[traffic_df.City == 'Merseyside']
traffic_dff4.groupby(['Area']).count()
# Out:
#             index   City  ONS LACode     CP  S Ref E  S Ref N  S_Ref_Latitude  \
# Area
# Knowsley     5460   5460        5460   5460     5460     5460            5460
# Liverpool   11748  11748       11748  11748    11748    11748           11748
# Sefton       4740   4740        4740   4740     4740     4740            4740
# St. Helens   3600   3600        3600   3600     3600     3600            3600
# Wirral       7320   7320        7320   7320     7320     7320            7320
#
#             S_Ref_Longitude   Road  Road_Name  ...      LGV  HGVR2  HGVR3  \
# Area                                           ...
# Knowsley               5460   5460       5196  ...     5460   5460   5460
# Liverpool             11748  11748      11724  ...    11748  11748  11748
# Sefton                 4740   4740       4668  ...     4740   4740   4740
# St. Helens             3600   3600       3528  ...     3600   3600   3600
# ...

# %%
traffic_dff5 = traffic_df[traffic_df.City == 'North East']
traffic_dff5.groupby(['Area']).count()
# Out:
#                       index   City  ONS LACode     CP  S Ref E  S Ref N  \
# Area
# Darlington             3408   3408        3408   3408     3408     3408
# Durham                14376  14376       14376  14376    14376    14376
# Gateshead              9708   9708        9708   9708     9708     9708
# Hartlepool             3144   3144        3144   3144     3144     3144
# Middlesbrough          6648   6648        6648   6648     6648     6648
# Newcastle upon Tyne   10044  10044       10044  10044    10044    10044
# North Tyneside         6359   6359        6359   6359     6359     6359
# Northumberland         7800   7800        7800   7800     7800     7800
# Redcar and Cleveland   4488   4488        4488   4488     4488     4488
# South Tyneside         4152   4152        4152   4152     4152     4152
# Stockton-on-Tees       6372   6372        6372   6372     6372     6372
# Sunderland             9060   9060        9060   9060     9060     9060
#
# ...

# %%
traffic_dff6 = traffic_df[traffic_df.City == 'North West']
traffic_dff6.groupby(['Area']).count()
# Out:
#                        index   City  ONS LACode     CP  S Ref E  S Ref N  \
# Area
# Blackburn with Darwen   3048   3048        3048   3048     3048     3048
# Blackpool               3756   3756        3756   3756     3756     3756
# Bolton                  8628   8628        8628   8628     8628     8628
# Bury                    4632   4632        4632   4632     4632     4632
# Cumbria                15144  15144       15144  15144    15144    15144
# East Cheshire          10968  10968       10968  10968    10968    10968
# Halton                  3600   3600        3600   3600     3600     3600
# Lancashire             36024  36024       36024  36024    36024    36024
# Manchester             11028  11028       11028  11028    11028    11028
# Oldham                  4464   4464        4464   4464     4464     4464
# Rochdale                4716   4716        4716   4716     4716     4716
# Salford                 5724   5724        5724   5724     5724     5724
# ...

# %%
traffic_dff7 = traffic_df[traffic_df.City == 'Scotland']
traffic_dff7.groupby(['Area']).count()[['Year','dCount','CAR','BUS', 'LGV','HGVR2','HGVR3','HGVR4','HGVA3','HGVA5','HGVA6','HGV','AMV','hours']]
# Out:
#                            Year  dCount   CAR   BUS   LGV  HGVR2  HGVR3  \
# Area
# Aberdeen City              3924    3924  3924  3924  3924   3924   3924
# Aberdeenshire              8040    8040  8040  8040  8040   8040   8040
# Angus                      3144    3144  3144  3144  3144   3144   3144
# Argyll & Bute              2256    2256  2256  2256  2256   2256   2256
# City of Edinburgh          7668    7668  7668  7668  7668   7668   7668
# Clackmannanshire            984     984   984   984   984    984    984
# Comhairle nan Eilean Siar  1548    1548  1548  1548  1548   1548   1548
# Dumfries & Galloway        4728    4728  4728  4728  4728   4728   4728
# Dundee City                2832    2832  2832  2832  2832   2832   2832
# East Ayrshire              2400    2400  2400  2400  2400   2400   2400
# East Dunbartonshire        1944    1944  1944  1944  1944   1944   1944
# East Lothian               2388    2388  2388  2388  2388   2388   2388
# ...

# %%
traffic_dff8 = traffic_df[traffic_df.City == 'South East']
traffic_dff8.groupby(['Area']).count()
# Out:
#                         index   City  ONS LACode     CP  S Ref E  S Ref N  \
# Area
# Bracknell Forest         3744   3744        3744   3744     3744     3744
# Brighton and Hove        7536   7536        7536   7536     7536     7536
# Buckinghamshire         18168  18168       18168  18168    18168    18168
# East Sussex             21180  21180       21180  21180    21180    21180
# Hampshire               54780  54780       54780  54780    54780    54780
# Isle of Wight            3144   3144        3144   3144     3144     3144
# Kent                    40728  40728       40728  40728    40728    40728
# Medway                   6216   6216        6216   6216     6216     6216
# Milton Keynes           11100  11100       11100  11100    11100    11100
# Oxfordshire             22644  22644       22644  22644    22644    22644
# Portsmouth               5076   5076        5076   5076     5076     5076
# Reading                  2988   2988        2988   2988     2988     2988
# ...

# %%
traffic_dff9 = traffic_df[traffic_df.City == 'South West']
traffic_dff9.groupby(['Area']).count()
# Out:
#                                     index   City  ONS LACode     CP  S Ref E  \
# Area
# Bath and North East Somerset         4836   4836        4836   4836     4836
# Bournemouth                          4860   4860        4860   4860     4860
# Bristol, City of                    12144  12144       12144  12144    12144
# Cornwall excluding Isles of Scilly  17052  17052       17052  17052    17052
# Devon                               22032  22032       22032  22032    22032
# Dorset                              17616  17616       17616  17616    17616
# Gloucestershire                     20528  20528       20528  20528    20528
# Isles of Scilly                       180    180         180    180      180
# North Somerset                       7584   7584        7584   7584     7584
# Plymouth                             7716   7716        7716   7716     7716
# Poole                                5088   5088        5088   5088     5088
# ...

# %%
traffic_dff10 = traffic_df[traffic_df.City == 'Wales']
traffic_dff10.groupby(['Area']).count()
# Out:
#                        index   City  ONS LACode     CP  S Ref E  S Ref N  \
# Area
# Blaenau Gwent           2184   2184        2184   2184     2184     2184
# Bridgend                4440   4440        4440   4440     4440     4440
# Caerphilly              6648   6648        6648   6648     6648     6648
# Cardiff                14664  14664       14664  14664    14664    14664
# Carmarthenshire         7440   7440        7440   7440     7440     7440
# Ceredigion              2628   2628        2628   2628     2628     2628
# Conwy                   3420   3420        3420   3420     3420     3420
# Denbighshire            3012   3012        3012   3012     3012     3012
# Flintshire              5016   5016        5016   5016     5016     5016
# Gwynedd                 3563   3563        3563   3563     3563     3563
# Isle of Anglesey        2256   2256        2256   2256     2256     2256
# Merthyr Tydfil          1776   1776        1776   1776     1776     1776
# ...

# %%
traffic_dff11 = traffic_df[traffic_df.City == 'West Midlands']
traffic_dff11.groupby(['Area']).count()
# Out:
#                           index   City  ONS LACode     CP  S Ref E  S Ref N  \
# Area
# Birmingham                32076  32076       32076  32076    32076    32076
# Coventry                  10980  10980       10980  10980    10980    10980
# Dudley                     8832   8832        8832   8832     8832     8832
# Herefordshire, County of   7104   7104        7104   7104     7104     7104
# Sandwell                   8808   8808        8808   8808     8808     8808
# Shropshire                10824  10824       10824  10824    10824    10824
# Solihull                   8880   8880        8880   8880     8880     8880
# Staffordshire             23052  23052       23052  23052    23052    23052
# Stoke-on-Trent             5124   5124        5124   5124     5124     5124
# Telford and Wrekin         7752   7752        7752   7752     7752     7752
# Walsall                    6060   6060        6060   6060     6060     6060
# ...

# %%
traffic_dff11 = traffic_df[traffic_df.City == 'Yorkshire & the Humber']
traffic_dff11.groupby(['Area']).count()
# Out:
#                              index   City  ONS LACode     CP  S Ref E  \
# Area
# Barnsley                      5952   5952        5952   5952     5952
# Bradford                     11913  11913       11913  11913    11913
# Calderdale                    4992   4992        4992   4992     4992
# Doncaster                     9180   9180        9180   9180     9180
# East Riding of Yorkshire     12168  12168       12168  12168    12168
# Kingston upon Hull, City of   7656   7656        7656   7656     7656
# Kirklees                      8280   8280        8280   8280     8280
# Leeds                        20352  20352       20352  20352    20352
# North East Lincolnshire       5172   5172        5172   5172     5172
# North Lincolnshire            5256   5256        5256   5256     5256
# North Yorkshire              23832  23832       23832  23832    23832
# Rotherham                     7704   7704        7704   7704     7704
# ...
